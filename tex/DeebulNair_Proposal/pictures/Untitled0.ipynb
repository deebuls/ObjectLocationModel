# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
# Out:
# /home/deebuls/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
np.random.seed(sum(map(ord, "distributions")))
x = np.random.normal(size=100)
sns.distplot(x);

# %%
s = np.random.dirichlet((20, 5,6, 4), 20)
print s
# Out:
# [[ 0.44966637  0.10223149  0.21732589  0.23077625]
#  [ 0.59583666  0.0713678   0.28761941  0.04517614]
#  [ 0.40815962  0.11651744  0.27208028  0.20324266]
#  [ 0.48303919  0.22442497  0.12356095  0.16897489]
#  [ 0.63783011  0.10866026  0.16190496  0.09160467]
#  [ 0.66455317  0.15224684  0.08629248  0.09690751]
#  [ 0.66232814  0.09175966  0.1581668   0.0877454 ]
#  [ 0.43170866  0.26851642  0.1901874   0.10958752]
#  [ 0.56485469  0.17237427  0.13797205  0.124799  ]
#  [ 0.61948626  0.08589565  0.24387484  0.05074325]
#  [ 0.60675778  0.12951234  0.0936291   0.17010078]
#  [ 0.54203935  0.21336391  0.10488429  0.13971245]
#  [ 0.50292545  0.29510117  0.18124926  0.02072412]
#  [ 0.55401217  0.08362033  0.16789542  0.19447209]
#  [ 0.51533453  0.21419656  0.15318866  0.11728025]
#  [ 0.66540209  0.15255807  0.06069328  0.12134656]
#  [ 0.61261     0.16934878  0.10798829  0.11005293]
#  [ 0.54775037  0.07685766  0.16022212  0.21516985]
#  [ 0.69254335  0.15347822  0.11592444  0.03805399]
#  [ 0.63330762  0.154449    0.11045495  0.10178843]]
